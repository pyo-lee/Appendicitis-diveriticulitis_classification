# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import numpy as np 
import os
import glob
#import cv2
#from libtiff import TIFF

def makeFolder():
    # make folder
    folder = []
    folder.append('D:/appendicitis/2_appendicitis-diverticultis/npy')
    split_num =5
    for i in range(1, split_num+1):
        folder.append('D:/appendicitis/2_appendicitis-diverticulitis/npy/exp%d'%i)
    for j in range(len(folder)):
        if not os.path.lexists(folder[j]):
            os.mkdir(folder[j])

class dataProcess(object):

    def __init__(self, out_rows, out_cols,
                 data1_path = "D:/appendicitis/4_exp2_rgb/5_appendicitis-diverticulitis/data/train", 
                 data2_path = "D:/appendicitis/4_exp2_rgb/5_appendicitis-diverticulitis/data/train",
                 test1_path = "D:/appendicitis/4_exp2_rgb/5_appendicitis-diverticulitis/data/test", 
                 test2_path = "D:/appendicitis/4_exp2_rgb/5_appendicitis-diverticulitis/data/test",  
                 npy_path = "D:/appendicitis/4_exp2_rgb/5_appendicitis-diverticulitis/npy", 
                 img_type = "png"):


        self.out_rows = out_rows
        self.out_cols = out_cols
        self.data1_path = data1_path
        self.data2_path = data2_path
        self.img_type = img_type
        self.test1_path = test1_path
        self.test2_path = test2_path
        self.npy_path = npy_path

    def create_train_data(self, index):
        i = 0
        print('-'*30)
        print('Creating training images...')
        print('-'*30)
        
        data1_path=self.data1_path+'/exp%d/appendicitis'%index
        imgs1 = glob.glob(data1_path+"/*."+self.img_type)

        print(len(imgs1))


        imgdatas1 = np.ndarray((len(imgs1),self.out_rows,self.out_cols,3), dtype=np.uint8)
        imglabels1 = np.ndarray((len(imgs1),1), dtype=np.uint8)
        
        for imgname in imgs1:
            midname = imgname[imgname.rindex("\\")+1:]

            img = load_img(data1_path + "/" + midname)
            img=img.resize((self.out_rows,self.out_cols))
            img = img_to_array(img)
            imgdatas1[i] = img
            imglabels1[i] = 0
            if i % 100 == 0:
                print('Done: {0}/{1} images'.format(i, len(imgs1)))
            i += 1
        print('loading done')
        np.save(self.npy_path +"/exp%d"%index+ '/train_appendicitis.npy', imgdatas1)
        np.save(self.npy_path +"/exp%d"%index+ '/label_appendicitis.npy', imglabels1)
        print('Saving to .npy files done. (1)')
        
        i = 0
        data2_path = self.data2_path+'/exp%d/diverticulitis'%index
        imgs2 = glob.glob(data2_path+"/*."+self.img_type)
        print(len(imgs2))
        imgdatas2 = np.ndarray((len(imgs2),self.out_rows,self.out_cols,3), dtype=np.uint8) #이 부분의 의미 알기!
        imglabels2 = np.ndarray((len(imgs2),1), dtype=np.uint8)
        for imgname in imgs2:
            midname = imgname[imgname.rindex("\\")+1:]

            img2 = load_img(data2_path + "/" + midname)

            img2=img2.resize((self.out_rows,self.out_cols))
            img2 = img_to_array(img2)
            imgdatas2[i] = img2
            imglabels2[i] = 1
            if i % 100 == 0:
                print('Done: {0}/{1} images'.format(i, len(imgs2)))
            i += 1
        print('loading done')
        np.save(self.npy_path + "/exp%d"%index+ '/train_diverticulitis.npy', imgdatas2)
        np.save(self.npy_path + "/exp%d"%index+ '/label_diverticulitis.npy', imglabels2)
        print('Saving to .npy files done. (2)')
        """
        i = 0
        imgs3 = glob.glob(self.data3_path+"/*."+self.img_type)
        print(len(imgs3))
        imgdatas3 = np.ndarray((len(imgs3),self.out_rows,self.out_cols,3), dtype=np.uint8)
        imglabels3 = np.ndarray((len(imgs3),1), dtype=np.uint8)
        for imgname in imgs3:
            midname = imgname[imgname.rindex("\\")+1:]
            img3 = load_img(self.data3_path + "/" + midname)
            img3=img3.resize((256,256))
            img3 = img_to_array(img3)
            imgdatas3[i] = img3
            imglabels3[i] = 2
            if i % 100 == 0:
                print('Done: {0}/{1} images'.format(i, len(imgs3)))
            i += 1
       
        print('loading done')
        np.save(self.npy_path + '/train3_256.npy', imgdatas3)
        np.save(self.npy_path + '/label3_256.npy', imglabels3)
        print('Saving to .npy files done. (3)')
        """
    def create_test_data(self, index):
        i = 0
        print('-'*30)
        print('Creating test images...')
        print('-'*30)
        test1_path = self.test1_path+'/exp%d/appendicitis'%index
        test2_path = self.test2_path+'/exp%d/diverticulitis'%index
        imgs1 = glob.glob(test1_path+"/*."+self.img_type)
        imgs2 = glob.glob(test2_path+"/*."+self.img_type)
        #imgs3 = glob.glob(self.test3_path+"/*."+self.img_type)
        print(len(imgs1))
        print(len(imgs2))
        #print(len(imgs3))

        imgdatas1 = np.ndarray((len(imgs1),self.out_rows,self.out_cols,3), dtype=np.uint8)
        imglabels1 = np.ndarray((len(imgs1),1), dtype=np.uint8)
        for imgname in imgs1:
            midname = imgname[imgname.rindex("\\")+1:]
            img = load_img(test1_path + "/" + midname)
            img=img.resize((self.out_rows,self.out_cols))
            img = img_to_array(img)
            imgdatas1[i] = img
            imglabels1[i] = 0
            i += 1
        print('loading done')
        np.save(self.npy_path + "/exp%d"%index+'/test_appendicitis.npy', imgdatas1)
        np.save(self.npy_path + "/exp%d"%index+'/test_label_appendicitis.npy', imglabels1)
        print('Saving to imgs_test.npy files done.(1)')

        i = 0
        imgdatas2 = np.ndarray((len(imgs2),self.out_rows,self.out_cols,3), dtype=np.uint8)
        imglabels2 = np.ndarray((len(imgs2),1), dtype=np.uint8)
        for imgname in imgs2:
            midname = imgname[imgname.rindex("\\")+1:]
            img = load_img(test2_path + "/" + midname)	
            img=img.resize((self.out_rows,self.out_cols))
            img = img_to_array(img)
            imgdatas2[i] = img
            imglabels2[i] = 1
            i += 1
        print('loading done')
        np.save(self.npy_path + "/exp%d"%index+'/test_diverticulitis.npy', imgdatas2)
        np.save(self.npy_path + "/exp%d"%index+'/test_label_diverticulitis.npy', imglabels2)
        print('Saving to imgs_test.npy files done.(2)')
        """
        i = 0
        imgdatas3 = np.ndarray((len(imgs3),self.out_rows,self.out_cols,3), dtype=np.uint8)
        imglabels3 = np.ndarray((len(imgs3),1), dtype=np.uint8)
        for imgname in imgs3:
            midname = imgname[imgname.rindex("\\")+1:]
            img = load_img(self.test3_path + "/" + midname)	
            img=img.resize((256,256))
            img = img_to_array(img)
            imgdatas3[i] = img
            imglabels3[i] = 2
            i += 1
        print('loading done')
        np.save(self.npy_path + '/test3_256.npy', imgdatas3)
        np.save(self.npy_path + '/test_label3_256.npy', imglabels3)
        print('Saving to imgs_test.npy files done.(3)')
        """

    def load_train_data(self):
        print('-'*30)
        print('load train images...')
        print('-'*30)
        imgs_train1 = np.load(self.npy_path+"/train1_256.npy")
        imgs_mask_train1 = np.load(self.npy_path+"/label1_256.npy")
        imgs_train1 = imgs_train1.astype(float)/255

        imgs_train2 = np.load(self.npy_path+"/train2_256.npy")
        imgs_mask_train2 = np.load(self.npy_path+"/label2_256.npy")
        imgs_train2 = imgs_train2.astype(float)/255

        imgs_train3 = np.load(self.npy_path+"/train3_256.npy")
        imgs_mask_train3 = np.load(self.npy_path+"/label3_256.npy")
        imgs_mask_train3[imgs_mask_train3==1] = 2
        imgs_train3 = imgs_train3.astype(float)/255

        imgs_train_tmp=np.append(imgs_train1,imgs_train2,axis=0)
        #imgs_train=np.append(imgs_train_tmp,imgs_train3,axis=0)

        imgs_mask_train_tmp=np.append(imgs_mask_train1,imgs_mask_train2,axis=0)
        #imgs_mask_train=np.append(imgs_mask_train_tmp,imgs_mask_train3,axis=0)
        #print(imgs_mask_train1[:5])
        #print(imgs_mask_train2[:5])
        #print(imgs_mask_train3[:5])


        print(imgs_train.shape)
        print(imgs_mask_train.shape)



        return imgs_train,imgs_mask_train

    def load_test_data(self):
        print('-'*30)
        print('load test images...')
        print('-'*30)
        imgs_test1 = np.load(self.npy_path+"/test1_256.npy")
        imgs_mask_test1 = np.load(self.npy_path+"/test_label1_256.npy")
        imgs_test1 = imgs_test1.astype(float)/255

        imgs_test2 = np.load(self.npy_path+"/test2_256.npy")
        imgs_mask_test2 = np.load(self.npy_path+"/test_label2_256.npy")
        imgs_test2 = imgs_test2.astype(float)/255
        """
        imgs_test3 = np.load(self.npy_path+"/test3_256.npy")
        imgs_mask_test3 = np.load(self.npy_path+"/test_label3_256.npy")
        imgs_mask_test3[imgs_mask_test3==1] = 2
        imgs_test3 = imgs_test3.astype(float)/255
        """
        print(imgs_mask_test1[:5])
        print(imgs_mask_test2[:5])
        #print(imgs_mask_test3[:5])

        imgs_test_tmp=np.append(imgs_test1,imgs_test2,axis=0)
        #imgs_test=np.append(imgs_test_tmp,imgs_test3,axis=0)

        imgs_mask_test_tmp=np.append(imgs_mask_test1,imgs_mask_test2,axis=0)
        #imgs_mask_test=np.append(imgs_mask_test_tmp,imgs_mask_test3,axis=0)
        print(imgs_test.shape)
        print(imgs_mask_test.shape)



        return imgs_test,imgs_mask_test

if __name__ == "__main__":

	#makeFolder()
	mydata = dataProcess(256,256)
	for index in range(1,6):
		print('exp%d strat'%index)
		mydata.create_train_data(index)
		mydata.create_test_data(index)
		print('exp%d done'%index)
		print('*'*30)
	#imgs_train,imgs_mask_train = mydata.load_train_data()  
	#imgs_test,imgs_mask_test = mydata.load_test_data()
# Out:
# exp1 strat
# ------------------------------
# Creating training images...
# ------------------------------
# 1567
# Done: 0/1567 images
# Done: 100/1567 images
# Done: 200/1567 images
# Done: 300/1567 images
# Done: 400/1567 images
# Done: 500/1567 images
# Done: 600/1567 images
# Done: 700/1567 images
# Done: 800/1567 images
# Done: 900/1567 images
# Done: 1000/1567 images
# Done: 1100/1567 images
# Done: 1200/1567 images
# Done: 1300/1567 images
# Done: 1400/1567 images
# Done: 1500/1567 images
# loading done
# Saving to .npy files done. (1)
# 1316
# Done: 0/1316 images
# Done: 100/1316 images
# Done: 200/1316 images
# Done: 300/1316 images
# Done: 400/1316 images
# Done: 500/1316 images
# Done: 600/1316 images
# Done: 700/1316 images
# Done: 800/1316 images
# Done: 900/1316 images
# Done: 1000/1316 images
# Done: 1100/1316 images
# Done: 1200/1316 images
# Done: 1300/1316 images
# loading done
# Saving to .npy files done. (2)
# ------------------------------
# Creating test images...
# ------------------------------
# 392
# 165
# loading done
# Saving to imgs_test.npy files done.(1)
# loading done
# Saving to imgs_test.npy files done.(2)
# exp1 done
# ******************************
# exp2 strat
# ------------------------------
# Creating training images...
# ------------------------------
# 1553
# Done: 0/1553 images
# Done: 100/1553 images
# Done: 200/1553 images
# Done: 300/1553 images
# Done: 400/1553 images
# Done: 500/1553 images
# Done: 600/1553 images
# Done: 700/1553 images
# Done: 800/1553 images
# Done: 900/1553 images
# Done: 1000/1553 images
# Done: 1100/1553 images
# Done: 1200/1553 images
# Done: 1300/1553 images
# Done: 1400/1553 images
# Done: 1500/1553 images
# loading done
# Saving to .npy files done. (1)
# 1310
# Done: 0/1310 images
# Done: 100/1310 images
# Done: 200/1310 images
# Done: 300/1310 images
# Done: 400/1310 images
# Done: 500/1310 images
# Done: 600/1310 images
# Done: 700/1310 images
# Done: 800/1310 images
# Done: 900/1310 images
# Done: 1000/1310 images
# Done: 1100/1310 images
# Done: 1200/1310 images
# Done: 1300/1310 images
# loading done
# Saving to .npy files done. (2)
# ------------------------------
# Creating test images...
# ------------------------------
# 406
# 168
# loading done
# Saving to imgs_test.npy files done.(1)
# loading done
# Saving to imgs_test.npy files done.(2)
# exp2 done
# ******************************
# exp3 strat
# ------------------------------
# Creating training images...
# ------------------------------
# 1554
# Done: 0/1554 images
# Done: 100/1554 images
# Done: 200/1554 images
# Done: 300/1554 images
# Done: 400/1554 images
# Done: 500/1554 images
# Done: 600/1554 images
# Done: 700/1554 images
# Done: 800/1554 images
# Done: 900/1554 images
# Done: 1000/1554 images
# Done: 1100/1554 images
# Done: 1200/1554 images
# Done: 1300/1554 images
# Done: 1400/1554 images
# Done: 1500/1554 images
# loading done
# Saving to .npy files done. (1)
# 1304
# Done: 0/1304 images
# Done: 100/1304 images
# Done: 200/1304 images
# Done: 300/1304 images
# Done: 400/1304 images
# Done: 500/1304 images
# Done: 600/1304 images
# Done: 700/1304 images
# Done: 800/1304 images
# Done: 900/1304 images
# Done: 1000/1304 images
# Done: 1100/1304 images
# Done: 1200/1304 images
# Done: 1300/1304 images
# loading done
# Saving to .npy files done. (2)
# ------------------------------
# Creating test images...
# ------------------------------
# 405
# 171
# loading done
# Saving to imgs_test.npy files done.(1)
# loading done
# Saving to imgs_test.npy files done.(2)
# exp3 done
# ******************************
# exp4 strat
# ------------------------------
# Creating training images...
# ------------------------------
# 1558
# Done: 0/1558 images
# Done: 100/1558 images
# Done: 200/1558 images
# Done: 300/1558 images
# Done: 400/1558 images
# Done: 500/1558 images
# Done: 600/1558 images
# Done: 700/1558 images
# Done: 800/1558 images
# Done: 900/1558 images
# Done: 1000/1558 images
# Done: 1100/1558 images
# Done: 1200/1558 images
# Done: 1300/1558 images
# Done: 1400/1558 images
# Done: 1500/1558 images
# loading done
# Saving to .npy files done. (1)
# 1308
# Done: 0/1308 images
# Done: 100/1308 images
# Done: 200/1308 images
# Done: 300/1308 images
# Done: 400/1308 images
# Done: 500/1308 images
# Done: 600/1308 images
# Done: 700/1308 images
# Done: 800/1308 images
# Done: 900/1308 images
# Done: 1000/1308 images
# Done: 1100/1308 images
# Done: 1200/1308 images
# Done: 1300/1308 images
# loading done
# Saving to .npy files done. (2)
# ------------------------------
# Creating test images...
# ------------------------------
# 401
# 169
# loading done
# Saving to imgs_test.npy files done.(1)
# loading done
# Saving to imgs_test.npy files done.(2)
# exp4 done
# ******************************
# exp5 strat
# ------------------------------
# Creating training images...
# ------------------------------
# 1604
# Done: 0/1604 images
# Done: 100/1604 images
# Done: 200/1604 images
# Done: 300/1604 images
# Done: 400/1604 images
# Done: 500/1604 images
# Done: 600/1604 images
# Done: 700/1604 images
# Done: 800/1604 images
# Done: 900/1604 images
# Done: 1000/1604 images
# Done: 1100/1604 images
# Done: 1200/1604 images
# Done: 1300/1604 images
# Done: 1400/1604 images
# Done: 1500/1604 images
# Done: 1600/1604 images
# loading done
# Saving to .npy files done. (1)
# 1346
# Done: 0/1346 images
# Done: 100/1346 images
# Done: 200/1346 images
# Done: 300/1346 images
# Done: 400/1346 images
# Done: 500/1346 images
# Done: 600/1346 images
# Done: 700/1346 images
# Done: 800/1346 images
# Done: 900/1346 images
# Done: 1000/1346 images
# Done: 1100/1346 images
# Done: 1200/1346 images
# Done: 1300/1346 images
# loading done
# Saving to .npy files done. (2)
# ------------------------------
# Creating test images...
# ------------------------------
# 355
# 150
# loading done
# Saving to imgs_test.npy files done.(1)
# loading done
# Saving to imgs_test.npy files done.(2)
# exp5 done
# ******************************
